# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error , mean_squared_error
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense

# %%
df = pd.read_csv('boston_train (1).csv')

# %%
df
# Out:
#       ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4      7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  500  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       18.7  394.63   2.94  33.4
# 3       18.7  396.90   5.33  36.2
# 4       15.2  395.60  12.43  22.9
# ..       ...     ...    ...   ...
# 328     19.2  395.77  15.10  17.5
# 329     21.0  391.99   9.67  22.4
# 330     21.0  396.90   9.08  20.6
# 331     21.0  396.90   5.64  23.9
# 332     21.0  396.90   7.88  11.9
#
# [333 rows x 15 columns]

# %%
plt.subplots(figsize=(12,8))
sns.heatmap(df.corr(), cmap = 'RdGy')
# Out:
# <Axes: >

# %%
df.head
# Out:
# <bound method NDFrame.head of       ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4      7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  500  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       18.7  394.63   2.94  33.4
# 3       18.7  396.90   5.33  36.2
# 4       15.2  395.60  12.43  22.9
# ..       ...     ...    ...   ...
# 328     19.2  395.77  15.10  17.5
# 329     21.0  391.99   9.67  22.4
# 330     21.0  396.90   9.08  20.6
# 331     21.0  396.90   5.64  23.9
# 332     21.0  396.90   7.88  11.9
#
# [333 rows x 15 columns]>

# %%
df.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
# Train-test split
X = df.drop('medv', axis=1)
y = df['medv']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

# %%
sns.pairplot(df, vars = ['lstat', 'ptratio', 'indus', 'tax', 'crim', 'nox', 'rad', 'age', 'medv'])
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Neural Network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = Sequential([
    Dense(units=128, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(units=64, activation='relu'),
    Dense(units=32, activation='relu'),
    Dense(units=16, activation='relu'),
    Dense(units=1)
])
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
history = model.fit(X_train_scaled, y_train, epochs=15, verbose=1, validation_split=0.05)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - loss: 544.5718 - mae: 21.8063 - val_loss: 651.6691 - val_mae: 23.7687
# Epoch 2/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 614.9244 - mae: 22.8274 - val_loss: 633.6893 - val_mae: 23.3801
# Epoch 3/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 569.3051 - mae: 22.1329 - val_loss: 607.5033 - val_mae: 22.8145
# Epoch 4/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 519.5341 - mae: 20.9344 - val_loss: 565.6578 - val_mae: 21.8901
# Epoch 5/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 513.6187 - mae: 20.7353 - val_loss: 494.0774 - val_mae: 20.2363
# Epoch 6/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 426.4211 - mae: 18.3065 - val_loss: 382.4057 - val_mae: 17.3453
# Epoch 7/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 343.0209 - mae: 15.9017 - val_loss: 220.3910 - val_mae: 12.5569
# Epoch 8/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 206.8906 - mae: 12.4344 - val_loss: 60.3336 - val_mae: 6.5883
# Epoch 9/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 118.5378 - mae: 8.3680 - val_loss: 28.6840 - val_mae: 3.4919
# Epoch 10/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 92.1778 - mae: 7.4508 - val_loss: 39.6542 - val_mae: 4.1819
# Epoch 11/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 67.2613 - mae: 6.4016 - val_loss: 19.6315 - val_mae: 3.1361
# Epoch 12/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 40.8934 - mae: 4.8624 - val_loss: 15.0375 - val_mae: 3.2755
# Epoch 13/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 40.6356 - mae: 4.6353 - val_loss: 13.9440 - val_mae: 3.1560
# Epoch 14/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 37.5082 - mae: 4.0638 - val_loss: 14.8962 - val_mae: 2.9742
# Epoch 15/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 26.5852 - mae: 3.8114 - val_loss: 15.1703 - val_mae: 2.9197

# %%
# Evaluation of the Neural Network
nn_predictions = model.predict(X_test_scaled)
nn_mse = mean_squared_error(y_test, nn_predictions)
nn_mae = mean_absolute_error(y_test, nn_predictions)
nn_rmse = np.sqrt(nn_mse)
print('Neural Network MAE:', nn_mae)
print('Neural Network MSE:', nn_mse)
print('Neural Network RMSE:', nn_rmse)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Neural Network MAE: 3.7628276753781447
# Neural Network MSE: 26.8518718641784
# Neural Network RMSE: 5.181879182707601

# %%
# Plot the predicted vs actual values for Neural Network
plt.figure(figsize=(10, 6))
plt.scatter(y_test, nn_predictions, alpha=0.6)
plt.title('Neural Network: Actual vs Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.show()
